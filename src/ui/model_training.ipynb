# %%
import os
import sys

notebook_dir = os.path.dirname(os.path.abspath('__file__'))
src_path = os.path.abspath(os.path.join(notebook_dir, '..'))
os.chdir(src_path)
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %%
from ui.model_training_ui import render
render()
# Out:
# VBox(children=(HTML(value='<h3 style="margin:8px 0">Batch Model Training</h3>'), HTML(value='<hr style="margin…

# %% [markdown]
# # Scratchpad

# %%
from modules.data_helper import load_data
from datetime import date

test_df = load_data("test", 
          start_date=date(2025, 4, 1), 
          end_date=date(2026, 3, 31)
        )
# Out:
# Fetching stock data from 2025-04-01 to 2026-03-31
#
# Started to read data
# Reading data from 2025-04-01 to 2026-03-30
# HistoricalDataProcessor.get_data took 109 seconds
# HistoricalDataProcessor.process took 110 seconds
# Successfully fetched 546498 records
# Columns: ['Date', 'BizDt', 'Sgmt', 'Src', 'FinInstrmTp', 'FinInstrmId', 'ISIN', 'Identifier', 'SctySrs', 'FinInstrmNm', 'Open', 'High', 'Low', 'Close', 'LastPric', 'PreviousClose', 'UndrlygPric', 'SttlmPric', 'Volume', 'Turnover', 'TtlNbOfTxsExctd', 'SsnId', 'NewBrdLotQty']
#
# Data Summary:
# Date range in data: 0        2025-04-01
# 1        2025-04-01
# 2        2025-04-01
# 3        2025-04-01
# 4        2025-04-01
#             ...
# 546493   2026-03-30
# 546494   2026-03-30
# 546495   2026-03-30
# 546496   2026-03-30
# 546497   2026-03-30
# Name: Date, Length: 546498, dtype: datetime64[us] to 2026-03-30 00:00:00
#
# First 5 records:
#
# Records: 546498
#         Date       BizDt Sgmt  Src FinInstrmTp  FinInstrmId          ISIN  \
# 0 2025-04-01  2025-04-01   CM  NSE         STK        16921  INE144J01027
# 1 2025-04-01  2025-04-01   CM  NSE         STK            4  INE253B01015
# 2 2025-04-01  2025-04-01   CM  NSE         STK        13061  INE466L01038
# 3 2025-04-01  2025-04-01   CM  NSE         STK        30105  INF579M01BB5
# 4 2025-04-01  2025-04-01   CM  NSE         STK         6232  INE748C01038
#
#    Identifier SctySrs                FinInstrmNm  ...   Close  LastPric  \
# 0   20MICRONS      EQ             20 MICRONS LTD  ...  206.81    209.00
# 1  21STCENMGM      EQ  21ST CENTURY MGMT SERVICE  ...   67.90     67.90
# 2      360ONE      EQ        360 ONE WAM LIMITED  ...  888.15    889.90
# 3     GOLD360      EQ        360ONEAMC - GOLD360  ...   90.25     90.30
# 4   3IINFOLTD      EQ        3I INFOTECH LIMITED  ...   21.83     21.95
#
#    PreviousClose  UndrlygPric  SttlmPric    Volume      Turnover  \
# 0            NaN          NaN     206.90  164514.0  3.342474e+07
# 1            NaN          NaN      67.90    5539.0  3.705237e+05
# 2            NaN          NaN     888.15  529235.0  4.814854e+08
# 3            NaN          NaN      90.25    1696.0  1.537395e+05
# 4            NaN          NaN      21.83  679150.0  1.468410e+07
#
#    TtlNbOfTxsExctd  SsnId  NewBrdLotQty
# 0             5824     F1             1
# 1               78     F1             1
# 2            35474     F1             1
# 3               37     F1             1
# 4             2074     F1             1
#
# [5 rows x 23 columns]
# LowestPriceInNextNDaysCalculationWorker took 1 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 1 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 1 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 1 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 1 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 1 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 1 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 1 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# RsiCalculationWorker took 6 seconds
# ColumnValueCrossedAboveFlagWorker took 0 seconds
# ColumnValueCrossedBelowFlagWorker took 0 seconds
# StochRsiCalculationWorker took 6 seconds
# ColumnValueCrossedAboveFlagWorker took 0 seconds
# ColumnValueCrossedAboveFlagWorker took 0 seconds
# ColumnValueCrossedBelowFlagWorker took 0 seconds
# ColumnValueCrossedBelowFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# StdDevCalculationWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# StdDevCalculationWorker took 0 seconds
# BollingerBandCalculationWorker took 1 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# StdDevCalculationWorker took 0 seconds
# BollingerBandCalculationWorker took 1 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# ColumnValueBelowFlagWorker took 0 seconds
# ColumnValueAboveFlagWorker took 0 seconds
# ColumnValueBelowFlagWorker took 0 seconds
# ColumnValueAboveFlagWorker took 0 seconds
# ColumnValueAboveAnotherColumnValueFlagWorker took 0 seconds
# ColumnValueAboveAnotherColumnValueFlagWorker took 0 seconds
# ColumnValueAboveAnotherColumnValueFlagWorker took 0 seconds
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:194: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:206: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:231: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = grouped[self._params['value_column']].transform(
# c:\Data\Study\ML\src\modules\calc_workers.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = data[self._params['value_column']] / data[sma_col]
# c:\Data\Study\ML\src\modules\calc_workers.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# ColumnSmaCalculationWorker took 0 seconds
# ColumnRelativeToSmaCalculationWorker took 0 seconds
# ColumnValueAboveScaledColumnValueFlagWorker took 0 seconds
# ColumnRisingWithVolumeConfirmationFlagWorker took 0 seconds
# c:\Data\Study\ML\src\modules\calc_workers.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = grouped[self._params['value_column']].transform(
# c:\Data\Study\ML\src\modules\calc_workers.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = data[self._params['value_column']] / data[sma_col]
# c:\Data\Study\ML\src\modules\calc_workers.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = data.groupby(BaseColumns.Date)[self._params['value_column']].rank(pct=True)
# c:\Data\Study\ML\src\modules\calc_workers.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# ColumnSmaCalculationWorker took 0 seconds
# ColumnRelativeToSmaCalculationWorker took 0 seconds
# ColumnValueAboveScaledColumnValueFlagWorker took 0 seconds
# ColumnRisingWithVolumeConfirmationFlagWorker took 0 seconds
# ColumnPercentileRankByDateCalculationWorker took 0 seconds
# DailyRangePercCalculationWorker took 0 seconds
# GapPercCalculationWorker took 0 seconds
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = identifier_grouped_data[self._params["value_column"]].transform(lambda x:
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:511: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[1]] = (
# ColumnChangeOverNDaysCalculationWorker took 0 seconds
# c:\Data\Study\ML\src\modules\calc_workers.py:151: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = result
# TargetHitDayCalculationWorker took 1 seconds
# c:\Data\Study\ML\src\modules\calc_workers.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = result
# StopHitDayCalculationWorker took 1 seconds
# Successfully processed and saved 546498 records to cache
# Fetching stock data from 2025-04-01 to 2026-03-31
#
# Started to read data
# Reading data from 2025-04-01 to 2026-03-30
# Data availability <class 'markets_insights.datareader.data_reader.NseIndicesReader'>: Status.COMPLETE, criteria: DateRangeCriteria(from_date=datetime.date(2025, 4, 1), to_date=datetime.date(2026, 3, 30))
# HistoricalDataProcessor.get_data took 6 seconds
# HistoricalDataProcessor.process took 6 seconds
# Successfully fetched 34750 records
# Columns: ['Identifier', 'Index Date', 'Open', 'High', 'Low', 'Close', 'Points Change', 'Change(%)', 'Volume', 'Turnover', 'P/E', 'P/B', 'Div Yield', 'Date', 'PreviousClose']
#
# Data Summary:
# Date range in data: 0                                    Nifty 50
# 1                               Nifty Next 50
# 2                                   Nifty 100
# 3                                   Nifty 200
# 4                                   Nifty 500
#                          ...
# 34745    Nifty BHARAT Bond Index - April 2031
# 34746    Nifty BHARAT Bond Index - April 2032
# 34747    Nifty BHARAT Bond Index - April 2033
# 34748                     Nifty 1D Rate Index
# 34749                             Nifty50 USD
# Name: Identifier, Length: 34750, dtype: str to Nifty50 USD
#
# First 5 records:
#
# Records: 34750
#       Identifier  Index Date      Open      High       Low     Close  \
# 0       Nifty 50  01-04-2025  23341.10  23565.15  23136.40  23165.70
# 1  Nifty Next 50  01-04-2025  62981.10  63339.15  62181.20  62372.10
# 2      Nifty 100  01-04-2025  23902.30  24110.60  23684.30  23713.80
# 3      Nifty 200  01-04-2025  12907.75  13018.80  12791.45  12809.30
# 4      Nifty 500  01-04-2025  21227.10  21398.35  21042.45  21070.75
#
#    Points Change Change(%)        Volume      Turnover    P/E   P/B Div Yield  \
# 0        -353.65      -1.5  3.751183e+08  3.068070e+11  21.05  3.43      1.34
# 1        -671.10     -1.06  1.931259e+08  1.095237e+11  21.26   3.9      1.46
# 2        -343.55     -1.43  5.682442e+08  4.163308e+11  21.09   3.5      1.36
# 3        -173.45     -1.34  3.429384e+09  5.885810e+11  22.34  3.63      1.29
# 4        -268.80     -1.26  3.960065e+09  7.488832e+11  23.25  3.68      1.22
#
#         Date  PreviousClose
# 0 2025-04-01            NaN
# 1 2025-04-01            NaN
# 2 2025-04-01            NaN
# 3 2025-04-01            NaN
# 4 2025-04-01            NaN
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# LowestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# HighestPriceInNextNDaysCalculationWorker took 0 seconds
# RsiCalculationWorker took 0 seconds
# ColumnValueCrossedAboveFlagWorker took 0 seconds
# ColumnValueCrossedBelowFlagWorker took 0 seconds
# StochRsiCalculationWorker took 0 seconds
# ColumnValueCrossedAboveFlagWorker took 0 seconds
# ColumnValueCrossedAboveFlagWorker took 0 seconds
# ColumnValueCrossedBelowFlagWorker took 0 seconds
# ColumnValueCrossedBelowFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# StdDevCalculationWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# StdDevCalculationWorker took 0 seconds
# BollingerBandCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# SmaCalculationWorker took 0 seconds
# StdDevCalculationWorker took 0 seconds
# BollingerBandCalculationWorker took 0 seconds
# PriceCrossedBelowColumnValueFlagWorker took 0 seconds
# PriceCrossedAboveColumnValueFlagWorker took 0 seconds
# ColumnValueBelowFlagWorker took 0 seconds
# ColumnValueAboveFlagWorker took 0 seconds
# ColumnValueBelowFlagWorker took 0 seconds
# ColumnValueAboveFlagWorker took 0 seconds
# ColumnValueAboveAnotherColumnValueFlagWorker took 0 seconds
# ColumnValueAboveAnotherColumnValueFlagWorker took 0 seconds
# ColumnValueAboveAnotherColumnValueFlagWorker took 0 seconds
# ColumnSmaCalculationWorker took 0 seconds
# ColumnRelativeToSmaCalculationWorker took 0 seconds
# ColumnValueAboveScaledColumnValueFlagWorker took 0 seconds
# ColumnRisingWithVolumeConfirmationFlagWorker took 0 seconds
# ColumnSmaCalculationWorker took 0 seconds
# ColumnRelativeToSmaCalculationWorker took 0 seconds
# ColumnValueAboveScaledColumnValueFlagWorker took 0 seconds
# ColumnRisingWithVolumeConfirmationFlagWorker took 0 seconds
# ColumnPercentileRankByDateCalculationWorker took 0 seconds
# DailyRangePercCalculationWorker took 0 seconds
# GapPercCalculationWorker took 0 seconds
# ColumnChangeOverNDaysCalculationWorker took 0 seconds
# TargetHitDayCalculationWorker took 0 seconds
# StopHitDayCalculationWorker took 0 seconds
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:206: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:231: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = grouped[self._params['value_column']].transform(
# c:\Data\Study\ML\src\modules\calc_workers.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = data[self._params['value_column']] / data[sma_col]
# c:\Data\Study\ML\src\modules\calc_workers.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = grouped[self._params['value_column']].transform(
# c:\Data\Study\ML\src\modules\calc_workers.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = data[self._params['value_column']] / data[sma_col]
# c:\Data\Study\ML\src\modules\calc_workers.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = data.groupby(BaseColumns.Date)[self._params['value_column']].rank(pct=True)
# c:\Data\Study\ML\src\modules\calc_workers.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = (
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = identifier_grouped_data[self._params["value_column"]].transform(lambda x:
# c:\Data\Study\ML\.venv\Lib\site-packages\markets_insights\calculations\base.py:511: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[1]] = (
# c:\Data\Study\ML\src\modules\calc_workers.py:151: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = result
# c:\Data\Study\ML\src\modules\calc_workers.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[self._columns[0]] = result
# Successfully processed and saved 34750 records to cache
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from modules.data_helper import load_data
#       2 from datetime import date
#       3
# ----> 4 test_df = load_data("test",
#       5           start_date=date(2025, 4, 1),
#       6           end_date=date(2026, 3, 31)
#       7         )
#
# File c:\Data\Study\ML\src\modules\data_helper.py:124, in load_data(data_identifier, start_date, end_date, force_refresh, includes)
#     122         # Merge Index data with main data
#     123         data = pd.merge(data, index_data[index_data['Identifier'] == identifier], on='Date', how='left', suffixes=('', f'__{identifier}'))
# --> 124     data.to_csv(file_path, index=False)
#     125 return data
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
#    3990             lineterminator=lineterminator,
#    3991             sep=sep,
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\io\formats\format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\io\formats\csvs.py:272, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)    260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
# --> 272     self._save()
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\io\formats\csvs.py:277, in CSVFormatter._save(self)
#     275 if self._need_to_save_header:
#     276     self._save_header()
# --> 277 self._save_body()
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\io\formats\csvs.py:315, in CSVFormatter._save_body(self)
#     313 if start_i >= end_i:
#     314     break
# --> 315 self._save_chunk(start_i, end_i)
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\io\formats\csvs.py:322, in CSVFormatter._save_chunk(self, start_i, end_i)
#     319 slicer = slice(start_i, end_i)
#     320 df = self.obj.iloc[slicer]
# --> 322 res = df._get_values_for_csv(**self._number_format)
#     323 data = list(res._iter_column_arrays())
#     325 ix = (
#     326     self.data_index[slicer]._get_values_for_csv(**self._number_format)
#     327     if self.nlevels != 0
#     328     else np.empty(end_i - start_i)
#     329 )
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\core\frame.py:1396, in DataFrame._get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#    1392         na_rep: str,
#    1393         quoting,  # int csv.QUOTE_FOO from stdlib
#    1394     ) -> DataFrame:
#    1395         # helper used by to_csv
# -> 1396         mgr = self._mgr.get_values_for_csv(
#    1397             float_format=float_format,
#    1398             date_format=date_format,
#    1399             decimal=decimal,
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\core\internals\managers.py:629, in BaseBlockManager.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     622 def get_values_for_csv(
#     623     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     624 ) -> Self:
#     625     """
#     626     Convert values to native types (strings / python objects) that are used
#     627     in formatting (repr / csv).
#     628     """
# --> 629     return self.apply(
#     630         "get_values_for_csv",
#     631         na_rep=na_rep,
#     632         quoting=quoting,
#     633         float_format=float_format,
#     634         date_format=date_format,
#     635         decimal=decimal,
#     636     )
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\core\internals\blocks.py:629, in Block.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     624 @final
#     625 def get_values_for_csv(
#     626     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     627 ) -> Block:
#     628     """convert to our native types format"""
# --> 629     result = get_values_for_csv(
#     630         self.values,
#     631         na_rep=na_rep,
#     632         quoting=quoting,
#     633         float_format=float_format,
#     634         date_format=date_format,
#     635         decimal=decimal,
#     636     )
#     637     return self.make_block(result)
#
# File c:\Data\Study\ML\.venv\Lib\site-packages\pandas\core\indexes\base.py:8149, in get_values_for_csv(values, date_format, na_rep, quoting, float_format, decimal)
#    8146 mask = isna(values)
#    8148 if not quoting:
# -> 8149     values = values.astype(str)
#    8150 else:
#    8151     values = np.array(values, dtype="object")
#
# KeyboardInterrupt:

# %%
test_df[[col for col in test_df.columns if "turn" in col]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test_df[[col for col in test_df.columns if "turn" in col]]
#
# NameError: name 'test_df' is not defined
